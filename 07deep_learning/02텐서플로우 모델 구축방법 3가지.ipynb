# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("../06machine_learning/data/Titanic_train.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data=data[['Survived', 'Pclass', 'Sex', 'Age','SibSp',
       'Parch','Embarked']]
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0           0       3    male  22.0      1      0        S
# 1           1       1  female  38.0      1      0        C
# 2           1       3  female  26.0      0      0        S
# 3           1       1  female  35.0      1      0        S
# 4           0       3    male  35.0      0      0        S
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0        S
# 887         1       1  female  19.0      0      0        S
# 888         0       3  female   NaN      1      2        S
# 889         1       1    male  26.0      0      0        C
# 890         0       3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
data['family']=data['SibSp']+data['Parch']

# %%
data=data.drop(['SibSp','Parch'],axis=1)

# %%
data
# Out:
#      Survived  Pclass     Sex   Age Embarked  family
# 0           0       3    male  22.0        S       1
# 1           1       1  female  38.0        C       1
# 2           1       3  female  26.0        S       0
# 3           1       1  female  35.0        S       1
# 4           0       3    male  35.0        S       0
# ..        ...     ...     ...   ...      ...     ...
# 886         0       2    male  27.0        S       0
# 887         1       1  female  19.0        S       0
# 888         0       3  female   NaN        S       3
# 889         1       1    male  26.0        C       0
# 890         0       3    male  32.0        Q       0
#
# [891 rows x 6 columns]

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data['Embarked']=data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   Embarked  891 non-null    object
#  5   family    891 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 41.9+ KB

# %%
X=data.drop('Survived',axis=1)
y=data['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,stratify=y,random_state=42)

# %% [markdown]
# # 딥러닝시에도 데이터의 스케일을 맞춰 주는것이 좋다.
# * StandardScaler, MinMaxScaler를 주로 사용, 이상값이 많을 경우 RobustScaler를 사용
# * 이진분류(0,1): MinMaxScaler
# * 연속값예측: StandardScaler

# %%
X_train
# Out:
#      Pclass     Sex        Age Embarked  family
# 748       1    male  19.000000        S       1
# 45        3    male  29.699118        S       0
# 28        3  female  29.699118        Q       0
# 633       1    male  29.699118        S       0
# 403       3    male  28.000000        S       1
# ..      ...     ...        ...      ...     ...
# 476       2    male  34.000000        S       1
# 190       2  female  32.000000        S       0
# 736       3  female  48.000000        S       4
# 462       1    male  47.000000        S       0
# 136       1  female  19.000000        S       2
#
# [623 rows x 5 columns]

# %%
cat_cols=X_train.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Sex', 'Embarked'], dtype='object')

# %%
num_cols=X_train.select_dtypes(exclude='object').columns
num_cols
# Out:
# Index(['Pclass', 'Age', 'family'], dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder

# %%
ohe=OneHotEncoder(handle_unknown='ignore',drop='first',sparse_output=False)
ohe.fit(X_train[cat_cols])
ohe_X_train=ohe.transform(X_train[cat_cols])
ohe_X_test=ohe.transform(X_test[cat_cols])
ohe_X_train_df=pd.DataFrame(ohe_X_train,columns=ohe.get_feature_names_out(), index=X_train.index)
ohe_X_test_df=pd.DataFrame(ohe_X_test,columns=ohe.get_feature_names_out(), index=X_test.index)
ohe_X_train_df
# Out:
#      Sex_male  Embarked_Q  Embarked_S
# 748       1.0         0.0         1.0
# 45        1.0         0.0         1.0
# 28        0.0         1.0         0.0
# 633       1.0         0.0         1.0
# 403       1.0         0.0         1.0
# ..        ...         ...         ...
# 476       1.0         0.0         1.0
# 190       0.0         0.0         1.0
# 736       0.0         0.0         1.0
# 462       1.0         0.0         1.0
# 136       0.0         0.0         1.0
#
# [623 rows x 3 columns]

# %%
mms=MinMaxScaler()
mms.fit(X_train[num_cols])
mms_X_train=mms.transform(X_train[num_cols])
mms_X_test=mms.transform(X_test[num_cols])
mms_X_train_df=pd.DataFrame(mms_X_train,columns=X_train[num_cols].columns, index=X_train.index)
mms_X_test_df=pd.DataFrame(mms_X_test,columns=X_test[num_cols].columns, index=X_test.index)
mms_X_train_df
# Out:
#      Pclass       Age  family
# 748     0.0  0.233476     0.1
# 45      1.0  0.367921     0.0
# 28      1.0  0.367921     0.0
# 633     0.0  0.367921     0.0
# 403     1.0  0.346569     0.1
# ..      ...       ...     ...
# 476     0.5  0.421965     0.1
# 190     0.5  0.396833     0.0
# 736     1.0  0.597889     0.4
# 462     0.0  0.585323     0.0
# 136     0.0  0.233476     0.2
#
# [623 rows x 3 columns]

# %%
X_train_df=pd.concat([mms_X_train_df,ohe_X_train_df],axis=1)
X_test_df=pd.concat([mms_X_test_df,ohe_X_test_df],axis=1)

# %%
X_test_df
# Out:
#      Pclass       Age  family  Sex_male  Embarked_Q  Embarked_S
# 625     0.0  0.761247     0.0       1.0         0.0         1.0
# 566     1.0  0.233476     0.0       1.0         0.0         1.0
# 459     1.0  0.367921     0.0       1.0         1.0         0.0
# 804     1.0  0.334004     0.0       1.0         0.0         1.0
# 338     1.0  0.560191     0.0       1.0         0.0         1.0
# ..      ...       ...     ...       ...         ...         ...
# 184     1.0  0.044986     0.2       0.0         0.0         1.0
# 607     0.0  0.334004     0.0       1.0         0.0         1.0
# 624     1.0  0.258608     0.0       1.0         0.0         1.0
# 103     1.0  0.409399     0.0       1.0         0.0         1.0
# 387     0.5  0.447097     0.0       0.0         0.0         1.0
#
# [268 rows x 6 columns]

# %% [markdown]
# # Tensorflow Sequential API를 사용한 순차적 모델 생성 및 분석
# * Sequential: 인공신경망을 순차적으로 작성할 때 사용
# * Dense: 층, 레이어
# * 1. 신경망 모델 정의
# * 2. 신경망 모델 훈련
# * 3. 훈련된 모델로 테스트
# * 4. 검증
#
# * 입력층은 반드시 독립변수의수(input_dim)를 정확히 지정
# * 신경망 모델의 은닉층은 2~3개 정도로 한다.
# * Dense의 노드수는 2의 배수의 지정 2 4 8 16 256
# * Dense의 노드는 큰 수에서 작은 수로 줄여나간다.
# * 은닉층의 활성화 함수: Relu
# * 출력층은 이진분류일 경우 sigmoid, 다중분류일 경우 softmax
# * 회귀분석일 경우(종속변수가 연속형(수치형)인 경우) 출력층에 활성화 함수 없이 노드를 1로 지정

# %%
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# 신경망 모델 정의 keras 3.0, tensorflow 2.19 기준
model=Sequential()
model.add(Input(shape=(X_train_df.shape[1],))) # 입력층
model.add(Dense(64,activation='relu')) # 은닉층
model.add(Dense(32,activation='relu')) # 은닉층
model.add(Dense(16,activation='relu')) # 은닉층
model.add(Dense(1,activation='sigmoid')) # 출력층, 이진분류이므로 sigmoid
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764648379.528169    1544 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1347 MB memory:  -> device: 0, name: NVIDIA GeForce MX450, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# #  모델의 파라미터 세팅 model.compile()
# * loss: 오차 계산 지표
#   * 이진분류: binary_crossentropy
#   * 다중분류: categorical_crossentropy - y가 one-hot encoding
#   * 데이터에 0이 많은 희소행렬인 경우: sparse_categorical_crossentropy - y label encoding
#   * 연속형데이터(회귀분석): mse
# * optimizer: learning_rate
#   * adam을 가장 많이 사용
# * metrics: 평가지표 accuracy

# %%
# 모델의 파라미터 세팅
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,073 (12.00 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 모델 훈련 model.fit(X_train, y_train)
# * epochs: 전체 데이터를 한 번 훈련하는 주기, 10-100 사이
# * batch_size: 전체 데이터를 쪼개서 훈련, 데이터의 묶음, 메모리에 맞춰서 크기 조절(2의 배수) 32, 64로 쪼개서 넣는 것 추천
# * validation_data: 검증 데이터로 모델 검증 실시

# %%
len(X_train_df)
# Out:
# 623

# %%
history=model.fit(X_train_df,y_train,epochs=100,batch_size=16,validation_data=(X_test_df,y_test))
# Out:
# Epoch 1/100
# 2025-12-02 13:18:31.171739: I external/local_xla/xla/service/service.cc:163] XLA service 0x75a1b400b4e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-02 13:18:31.171784: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce MX450, Compute Capability 7.5
# 2025-12-02 13:18:31.230502: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-02 13:18:31.556162: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 32/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5219 - loss: 0.6963
# I0000 00:00:1764649112.953927    1662 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6838 - loss: 0.6585 - val_accuracy: 0.7873 - val_loss: 0.6055
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7865 - loss: 0.5583 - val_accuracy: 0.8060 - val_loss: 0.5111
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8010 - loss: 0.4820 - val_accuracy: 0.7463 - val_loss: 0.5026
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7994 - loss: 0.4615 - val_accuracy: 0.7836 - val_loss: 0.4615
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8074 - loss: 0.4510 - val_accuracy: 0.7836 - val_loss: 0.4570
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8026 - loss: 0.4486 - val_accuracy: 0.8172 - val_loss: 0.4453
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8026 - loss: 0.4421 - val_accuracy: 0.8172 - val_loss: 0.4425
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8154 - loss: 0.4377 - val_accuracy: 0.7836 - val_loss: 0.4443
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8074 - loss: 0.4366 - val_accuracy: 0.8172 - val_loss: 0.4374
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8090 - loss: 0.4337 - val_accuracy: 0.8134 - val_loss: 0.4344
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8170 - loss: 0.4300 - val_accuracy: 0.8172 - val_loss: 0.4333
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8202 - loss: 0.4306 - val_accuracy: 0.8060 - val_loss: 0.4356
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8106 - loss: 0.4332 - val_accuracy: 0.8172 - val_loss: 0.4309
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8234 - loss: 0.4264 - val_accuracy: 0.8172 - val_loss: 0.4311
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8138 - loss: 0.4281 - val_accuracy: 0.8172 - val_loss: 0.4293
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8234 - loss: 0.4219 - val_accuracy: 0.8172 - val_loss: 0.4275
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8138 - loss: 0.4215 - val_accuracy: 0.7910 - val_loss: 0.4383
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8170 - loss: 0.4236 - val_accuracy: 0.8246 - val_loss: 0.4362
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8186 - loss: 0.4236 - val_accuracy: 0.8097 - val_loss: 0.4271
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8122 - loss: 0.4281 - val_accuracy: 0.7985 - val_loss: 0.4282
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8154 - loss: 0.4204 - val_accuracy: 0.8022 - val_loss: 0.4291
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8170 - loss: 0.4173 - val_accuracy: 0.8209 - val_loss: 0.4318
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8154 - loss: 0.4179 - val_accuracy: 0.8209 - val_loss: 0.4291
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8138 - loss: 0.4238 - val_accuracy: 0.8209 - val_loss: 0.4262
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8202 - loss: 0.4145 - val_accuracy: 0.7985 - val_loss: 0.4280
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8234 - loss: 0.4225 - val_accuracy: 0.7836 - val_loss: 0.4314
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8186 - loss: 0.4206 - val_accuracy: 0.8209 - val_loss: 0.4262
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8202 - loss: 0.4168 - val_accuracy: 0.8134 - val_loss: 0.4250
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8250 - loss: 0.4168 - val_accuracy: 0.8134 - val_loss: 0.4273
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8154 - loss: 0.4178 - val_accuracy: 0.8134 - val_loss: 0.4253
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.4121 - val_accuracy: 0.8097 - val_loss: 0.4241
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8331 - loss: 0.4100 - val_accuracy: 0.7873 - val_loss: 0.4309
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8186 - loss: 0.4131 - val_accuracy: 0.8172 - val_loss: 0.4243
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8266 - loss: 0.4135 - val_accuracy: 0.7948 - val_loss: 0.4340
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8234 - loss: 0.4111 - val_accuracy: 0.8172 - val_loss: 0.4249
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8347 - loss: 0.4091 - val_accuracy: 0.8134 - val_loss: 0.4232
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8347 - loss: 0.4065 - val_accuracy: 0.8209 - val_loss: 0.4252
# Epoch 38/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8331 - loss: 0.4096 - val_accuracy: 0.8022 - val_loss: 0.4250
# Epoch 39/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8347 - loss: 0.4041 - val_accuracy: 0.7985 - val_loss: 0.4268
# Epoch 40/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8363 - loss: 0.4046 - val_accuracy: 0.8060 - val_loss: 0.4236
# Epoch 41/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8331 - loss: 0.4032 - val_accuracy: 0.8246 - val_loss: 0.4276
# Epoch 42/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8315 - loss: 0.4050 - val_accuracy: 0.8097 - val_loss: 0.4252
# Epoch 43/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8299 - loss: 0.4018 - val_accuracy: 0.8097 - val_loss: 0.4252
# Epoch 44/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8347 - loss: 0.4053 - val_accuracy: 0.8172 - val_loss: 0.4258
# Epoch 45/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8363 - loss: 0.4024 - val_accuracy: 0.7985 - val_loss: 0.4264
# Epoch 46/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8347 - loss: 0.3986 - val_accuracy: 0.8060 - val_loss: 0.4327
# Epoch 47/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8363 - loss: 0.4029 - val_accuracy: 0.7836 - val_loss: 0.4370
# Epoch 48/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8347 - loss: 0.4011 - val_accuracy: 0.7948 - val_loss: 0.4298
# Epoch 49/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8427 - loss: 0.3960 - val_accuracy: 0.7724 - val_loss: 0.4432
# Epoch 50/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8299 - loss: 0.4038 - val_accuracy: 0.7761 - val_loss: 0.4454
# Epoch 51/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8379 - loss: 0.3996 - val_accuracy: 0.8209 - val_loss: 0.4259
# Epoch 52/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8299 - loss: 0.4029 - val_accuracy: 0.8209 - val_loss: 0.4362
# Epoch 53/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8379 - loss: 0.3979 - val_accuracy: 0.8097 - val_loss: 0.4285
# Epoch 54/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8299 - loss: 0.3969 - val_accuracy: 0.8022 - val_loss: 0.4312
# Epoch 55/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8347 - loss: 0.4018 - val_accuracy: 0.8172 - val_loss: 0.4330
# Epoch 56/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8347 - loss: 0.3960 - val_accuracy: 0.7910 - val_loss: 0.4365
# Epoch 57/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8411 - loss: 0.3946 - val_accuracy: 0.8060 - val_loss: 0.4409
# Epoch 58/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8379 - loss: 0.3934 - val_accuracy: 0.8060 - val_loss: 0.4335
# Epoch 59/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8347 - loss: 0.3962 - val_accuracy: 0.7985 - val_loss: 0.4393
# Epoch 60/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8411 - loss: 0.3930 - val_accuracy: 0.7985 - val_loss: 0.4294
# Epoch 61/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8443 - loss: 0.3895 - val_accuracy: 0.8134 - val_loss: 0.4296
# Epoch 62/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8363 - loss: 0.3872 - val_accuracy: 0.8022 - val_loss: 0.4335
# Epoch 63/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8475 - loss: 0.3873 - val_accuracy: 0.7985 - val_loss: 0.4418
# Epoch 64/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8266 - loss: 0.3894 - val_accuracy: 0.8134 - val_loss: 0.4316
# Epoch 65/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8379 - loss: 0.3856 - val_accuracy: 0.8097 - val_loss: 0.4361
# Epoch 66/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8411 - loss: 0.3886 - val_accuracy: 0.8134 - val_loss: 0.4355
# Epoch 67/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8427 - loss: 0.3858 - val_accuracy: 0.7985 - val_loss: 0.4377
# Epoch 68/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8379 - loss: 0.3854 - val_accuracy: 0.8022 - val_loss: 0.4373
# Epoch 69/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8411 - loss: 0.3842 - val_accuracy: 0.7910 - val_loss: 0.4509
# Epoch 70/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8379 - loss: 0.3892 - val_accuracy: 0.7724 - val_loss: 0.4814
# Epoch 71/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8395 - loss: 0.3842 - val_accuracy: 0.8097 - val_loss: 0.4432
# Epoch 72/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8427 - loss: 0.3847 - val_accuracy: 0.7985 - val_loss: 0.4424
# Epoch 73/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8363 - loss: 0.3836 - val_accuracy: 0.8022 - val_loss: 0.4439
# Epoch 74/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8347 - loss: 0.3821 - val_accuracy: 0.8134 - val_loss: 0.4446
# Epoch 75/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8395 - loss: 0.3800 - val_accuracy: 0.7724 - val_loss: 0.4657
# Epoch 76/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8299 - loss: 0.3854 - val_accuracy: 0.8134 - val_loss: 0.4442
# Epoch 77/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8379 - loss: 0.3818 - val_accuracy: 0.8097 - val_loss: 0.4441
# Epoch 78/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8411 - loss: 0.3825 - val_accuracy: 0.8172 - val_loss: 0.4443
# Epoch 79/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8395 - loss: 0.3847 - val_accuracy: 0.7985 - val_loss: 0.4496
# Epoch 80/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8427 - loss: 0.3761 - val_accuracy: 0.8209 - val_loss: 0.4458
# Epoch 81/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8395 - loss: 0.3889 - val_accuracy: 0.7985 - val_loss: 0.4534
# Epoch 82/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8395 - loss: 0.3806 - val_accuracy: 0.7948 - val_loss: 0.4551
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8459 - loss: 0.3787 - val_accuracy: 0.7985 - val_loss: 0.4554
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8379 - loss: 0.3826 - val_accuracy: 0.7687 - val_loss: 0.4825
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8459 - loss: 0.3800 - val_accuracy: 0.7761 - val_loss: 0.4697
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8443 - loss: 0.3807 - val_accuracy: 0.7687 - val_loss: 0.4780
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8395 - loss: 0.3768 - val_accuracy: 0.8097 - val_loss: 0.4520
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8347 - loss: 0.3790 - val_accuracy: 0.7948 - val_loss: 0.4627
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8443 - loss: 0.3772 - val_accuracy: 0.8060 - val_loss: 0.4525
# Epoch 90/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8379 - loss: 0.3784 - val_accuracy: 0.7687 - val_loss: 0.4808
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8491 - loss: 0.3751 - val_accuracy: 0.8172 - val_loss: 0.4616
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8411 - loss: 0.3736 - val_accuracy: 0.8060 - val_loss: 0.4632
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8491 - loss: 0.3733 - val_accuracy: 0.7985 - val_loss: 0.4627
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8427 - loss: 0.3776 - val_accuracy: 0.7873 - val_loss: 0.4781
# Epoch 95/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8475 - loss: 0.3721 - val_accuracy: 0.8097 - val_loss: 0.4605
# Epoch 96/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8379 - loss: 0.3746 - val_accuracy: 0.8172 - val_loss: 0.4698
# Epoch 97/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8491 - loss: 0.3731 - val_accuracy: 0.8022 - val_loss: 0.4792
# Epoch 98/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8459 - loss: 0.3735 - val_accuracy: 0.7948 - val_loss: 0.4799
# Epoch 99/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8475 - loss: 0.3710 - val_accuracy: 0.8060 - val_loss: 0.4671
# Epoch 100/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8459 - loss: 0.3752 - val_accuracy: 0.7873 - val_loss: 0.4838

# %% [markdown]
# # 딥러닝 모델 성능 평가
# * 딥러닝에서 모델의 성능을 평가하는 지표는 loss
# * 보통 loss가 낮으면 accuracy가 올라가지만 비례하지 않을 때도 있음.
# * accuracy와 loss 간의 차이가 있을 때 loss가 낮은 모델이 우수한 모델

# %%
score=model.evaluate(X_test_df,y_test)
print('test_loss: ',score[0])
print('test_accuracy: ',score[1])
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7873 - loss: 0.4838
# test_loss:  0.4837677776813507
# test_accuracy:  0.7873134613037109

# %%
for i in history.history:
    print(f"{i}:", history.history[i])
# Out:
# accuracy: [0.6837881207466125, 0.7865168452262878, 0.8009631037712097, 0.7993579506874084, 0.80738365650177, 0.8025681972503662, 0.8025681972503662, 0.8154093027114868, 0.80738365650177, 0.8089887499809265, 0.8170144557952881, 0.8202247023582458, 0.8105939030647278, 0.8234350085258484, 0.8138041496276855, 0.8234350085258484, 0.8138041496276855, 0.8170144557952881, 0.8186196088790894, 0.812199056148529, 0.8154093027114868, 0.8170144557952881, 0.8154093027114868, 0.8138041496276855, 0.8202247023582458, 0.8234350085258484, 0.8186196088790894, 0.8202247023582458, 0.8250401020050049, 0.8154093027114868, 0.8250401020050049, 0.8330658078193665, 0.8186196088790894, 0.8266452550888062, 0.8234350085258484, 0.8346709609031677, 0.8346709609031677, 0.8330658078193665, 0.8346709609031677, 0.8362760543823242, 0.8330658078193665, 0.8314606547355652, 0.8298555612564087, 0.8346709609031677, 0.8362760543823242, 0.8346709609031677, 0.8362760543823242, 0.8346709609031677, 0.8426966071128845, 0.8298555612564087, 0.8378812074661255, 0.8298555612564087, 0.8378812074661255, 0.8298555612564087, 0.8346709609031677, 0.8346709609031677, 0.841091513633728, 0.8378812074661255, 0.8346709609031677, 0.841091513633728, 0.8443017601966858, 0.8362760543823242, 0.8475120663642883, 0.8266452550888062, 0.8378812074661255, 0.841091513633728, 0.8426966071128845, 0.8378812074661255, 0.841091513633728, 0.8378812074661255, 0.8394863605499268, 0.8426966071128845, 0.8362760543823242, 0.8346709609031677, 0.8394863605499268, 0.8298555612564087, 0.8378812074661255, 0.841091513633728, 0.8394863605499268, 0.8426966071128845, 0.8394863605499268, 0.8394863605499268, 0.8459069132804871, 0.8378812074661255, 0.8459069132804871, 0.8443017601966858, 0.8394863605499268, 0.8346709609031677, 0.8443017601966858, 0.8378812074661255, 0.8491171598434448, 0.841091513633728, 0.8491171598434448, 0.8426966071128845, 0.8475120663642883, 0.8378812074661255, 0.8491171598434448, 0.8459069132804871, 0.8475120663642883, 0.8459069132804871]
# loss: [0.6585409045219421, 0.5583382248878479, 0.4820078909397125, 0.4614717364311218, 0.45103076100349426, 0.44864022731781006, 0.4420727789402008, 0.43767815828323364, 0.4365873634815216, 0.43370190262794495, 0.4299587905406952, 0.43056222796440125, 0.4332191050052643, 0.4263792037963867, 0.42809298634529114, 0.42192593216896057, 0.42151814699172974, 0.42362409830093384, 0.42363330721855164, 0.4280630648136139, 0.4203946888446808, 0.4172529876232147, 0.41788679361343384, 0.42376330494880676, 0.41446182131767273, 0.42252880334854126, 0.4206051230430603, 0.4167679250240326, 0.4168156087398529, 0.41775521636009216, 0.4121052026748657, 0.4100390672683716, 0.41306358575820923, 0.41353219747543335, 0.4111221432685852, 0.4091021418571472, 0.406494140625, 0.40959763526916504, 0.40408873558044434, 0.4046218991279602, 0.403169721364975, 0.40500131249427795, 0.4018287658691406, 0.4053199887275696, 0.4024021029472351, 0.39863720536231995, 0.40291884541511536, 0.4010622799396515, 0.3959519863128662, 0.4037923514842987, 0.39960160851478577, 0.40293869376182556, 0.39793264865875244, 0.3968752920627594, 0.4018012285232544, 0.3960111141204834, 0.3946230709552765, 0.393388569355011, 0.3962375521659851, 0.3929966390132904, 0.38949647545814514, 0.38721728324890137, 0.3873113989830017, 0.38938769698143005, 0.38558223843574524, 0.3886388838291168, 0.38579827547073364, 0.3854033946990967, 0.3842242956161499, 0.38918372988700867, 0.38416868448257446, 0.3847304582595825, 0.38361799716949463, 0.38210776448249817, 0.37999871373176575, 0.38539156317710876, 0.38184258341789246, 0.38247302174568176, 0.3847230076789856, 0.37609148025512695, 0.38892653584480286, 0.38057494163513184, 0.37868112325668335, 0.3825705051422119, 0.38002848625183105, 0.38072681427001953, 0.37683621048927307, 0.3790360391139984, 0.37715718150138855, 0.37839454412460327, 0.37505102157592773, 0.3736388087272644, 0.3732530474662781, 0.3776288330554962, 0.3721051514148712, 0.37461885809898376, 0.3731236457824707, 0.37353768944740295, 0.3710061013698578, 0.3751595616340637]
# val_accuracy: [0.7873134613037109, 0.8059701323509216, 0.746268630027771, 0.7835820913314819, 0.7835820913314819, 0.8171641826629639, 0.8171641826629639, 0.7835820913314819, 0.8171641826629639, 0.8134328126907349, 0.8171641826629639, 0.8059701323509216, 0.8171641826629639, 0.8171641826629639, 0.8171641826629639, 0.8171641826629639, 0.7910447716712952, 0.8246268630027771, 0.8097015023231506, 0.7985074520111084, 0.8022388219833374, 0.8208954930305481, 0.8208954930305481, 0.8208954930305481, 0.7985074520111084, 0.7835820913314819, 0.8208954930305481, 0.8134328126907349, 0.8134328126907349, 0.8134328126907349, 0.8097015023231506, 0.7873134613037109, 0.8171641826629639, 0.7947761416435242, 0.8171641826629639, 0.8134328126907349, 0.8208954930305481, 0.8022388219833374, 0.7985074520111084, 0.8059701323509216, 0.8246268630027771, 0.8097015023231506, 0.8097015023231506, 0.8171641826629639, 0.7985074520111084, 0.8059701323509216, 0.7835820913314819, 0.7947761416435242, 0.7723880410194397, 0.7761194109916687, 0.8208954930305481, 0.8208954930305481, 0.8097015023231506, 0.8022388219833374, 0.8171641826629639, 0.7910447716712952, 0.8059701323509216, 0.8059701323509216, 0.7985074520111084, 0.7985074520111084, 0.8134328126907349, 0.8022388219833374, 0.7985074520111084, 0.8134328126907349, 0.8097015023231506, 0.8134328126907349, 0.7985074520111084, 0.8022388219833374, 0.7910447716712952, 0.7723880410194397, 0.8097015023231506, 0.7985074520111084, 0.8022388219833374, 0.8134328126907349, 0.7723880410194397, 0.8134328126907349, 0.8097015023231506, 0.8171641826629639, 0.7985074520111084, 0.8208954930305481, 0.7985074520111084, 0.7947761416435242, 0.7985074520111084, 0.7686567306518555, 0.7761194109916687, 0.7686567306518555, 0.8097015023231506, 0.7947761416435242, 0.8059701323509216, 0.7686567306518555, 0.8171641826629639, 0.8059701323509216, 0.7985074520111084, 0.7873134613037109, 0.8097015023231506, 0.8171641826629639, 0.8022388219833374, 0.7947761416435242, 0.8059701323509216, 0.7873134613037109]
# val_loss: [0.6054860949516296, 0.5110895037651062, 0.5026379823684692, 0.46145516633987427, 0.4569745361804962, 0.4452752470970154, 0.4425005316734314, 0.4442506432533264, 0.43744760751724243, 0.4344068467617035, 0.4332942068576813, 0.43560779094696045, 0.4308778643608093, 0.4311125576496124, 0.429328590631485, 0.42753124237060547, 0.43825268745422363, 0.4361977279186249, 0.4271295666694641, 0.4281873106956482, 0.4291374981403351, 0.4317917227745056, 0.42914000153541565, 0.4261680543422699, 0.4279758036136627, 0.4313932955265045, 0.4261566996574402, 0.4249686896800995, 0.42732489109039307, 0.4253460466861725, 0.4240858256816864, 0.4309080243110657, 0.4242972135543823, 0.43395015597343445, 0.42491063475608826, 0.4232085645198822, 0.4252396523952484, 0.4250235855579376, 0.42677783966064453, 0.42357057332992554, 0.4275754988193512, 0.42522886395454407, 0.4251956045627594, 0.42575106024742126, 0.426434189081192, 0.43271830677986145, 0.4370343089103699, 0.4297686815261841, 0.44319698214530945, 0.4454241693019867, 0.4259417653083801, 0.4361817240715027, 0.4284781515598297, 0.43121254444122314, 0.433049738407135, 0.4365413784980774, 0.4409414231777191, 0.4335051476955414, 0.43925946950912476, 0.42935824394226074, 0.4296184778213501, 0.43346327543258667, 0.4417993128299713, 0.43155017495155334, 0.43612852692604065, 0.4354516863822937, 0.43772274255752563, 0.43726643919944763, 0.4509100615978241, 0.481423556804657, 0.4432491362094879, 0.4424497187137604, 0.44386574625968933, 0.4445899426937103, 0.46573981642723083, 0.4441717863082886, 0.44407302141189575, 0.4443069100379944, 0.4495646357536316, 0.44580936431884766, 0.4534236788749695, 0.4551413357257843, 0.45541033148765564, 0.482471764087677, 0.4696892499923706, 0.47803279757499695, 0.4519517719745636, 0.4627411365509033, 0.4524539113044739, 0.4807637333869934, 0.4615730941295624, 0.463162362575531, 0.46274667978286743, 0.4780753552913666, 0.4604647755622864, 0.4698250889778137, 0.4792490005493164, 0.479938805103302, 0.4671390652656555, 0.4837678372859955]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoches')
plt.ylabel('loss')
plt.legend(['train','val'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
