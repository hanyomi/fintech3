# %% [markdown]
# # 환경설정(폰트 설정)

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from seaborn import load_dataset
from matplotlib import font_manager, rcParams
warnings.filterwarnings("ignore")

candidates = ["Malgun Gothic", "AppleGothic", "NanumGothic", "Noto Sans CJK KR"]
avail = {f.name for f in font_manager.fontManager.ttflist}
for name in candidates:
    if name in avail:
        rcParams["font.family"] = name
        break
rcParams["axes.unicode_minus"] = False

print("Font set to:", rcParams["font.family"])
print("Seaborn:", sns.__version__)
# Out:
# Font set to: ['Malgun Gothic']
# Seaborn: 0.13.2

# %%
DATASETS = ["tips", "penguins", "flights", "iris", "car_crashes", "exercise"]
data = {name: load_dataset(name) for name in DATASETS}

# %%
data
# Out:
# {'tips':      total_bill   tip     sex smoker   day    time  size
#  0         16.99  1.01  Female     No   Sun  Dinner     2
#  1         10.34  1.66    Male     No   Sun  Dinner     3
#  2         21.01  3.50    Male     No   Sun  Dinner     3
#  3         23.68  3.31    Male     No   Sun  Dinner     2
#  4         24.59  3.61  Female     No   Sun  Dinner     4
#  ..          ...   ...     ...    ...   ...     ...   ...
#  239       29.03  5.92    Male     No   Sat  Dinner     3
#  240       27.18  2.00  Female    Yes   Sat  Dinner     2
#  241       22.67  2.00    Male    Yes   Sat  Dinner     2
#  242       17.82  1.75    Male     No   Sat  Dinner     2
#  243       18.78  3.00  Female     No  Thur  Dinner     2
#
#  [244 rows x 7 columns],
#  'penguins':     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
#  0    Adelie  Torgersen            39.1           18.7              181.0
#  1    Adelie  Torgersen            39.5           17.4              186.0
#  2    Adelie  Torgersen            40.3           18.0              195.0
#  3    Adelie  Torgersen             NaN            NaN                NaN
#  4    Adelie  Torgersen            36.7           19.3              193.0
#  ..      ...        ...             ...            ...                ...
#  339  Gentoo     Biscoe             NaN            NaN                NaN
#  340  Gentoo     Biscoe            46.8           14.3              215.0
#  341  Gentoo     Biscoe            50.4           15.7              222.0
#  342  Gentoo     Biscoe            45.2           14.8              212.0
#  343  Gentoo     Biscoe            49.9           16.1              213.0
#
#       body_mass_g     sex
#  0         3750.0    Male
#  1         3800.0  Female
#  2         3250.0  Female
#  3            NaN     NaN
#  4         3450.0  Female
#  ..           ...     ...
#  339          NaN     NaN
#  340       4850.0  Female
#  341       5750.0    Male
#  342       5200.0  Female
#  343       5400.0    Male
#
#  [344 rows x 7 columns],
#  'flights':      year month  passengers
#  0    1949   Jan         112
#  1    1949   Feb         118
#  2    1949   Mar         132
#  3    1949   Apr         129
#  4    1949   May         121
#  ..    ...   ...         ...
#  139  1960   Aug         606
#  140  1960   Sep         508
#  141  1960   Oct         461
#  142  1960   Nov         390
#  143  1960   Dec         432
#
#  [144 rows x 3 columns],
#  'iris':      sepal_length  sepal_width  petal_length  petal_width    species
#  0             5.1          3.5           1.4          0.2     setosa
#  1             4.9          3.0           1.4          0.2     setosa
#  2             4.7          3.2           1.3          0.2     setosa
#  3             4.6          3.1           1.5          0.2     setosa
#  4             5.0          3.6           1.4          0.2     setosa
#  ..            ...          ...           ...          ...        ...
#  145           6.7          3.0           5.2          2.3  virginica
#  146           6.3          2.5           5.0          1.9  virginica
#  147           6.5          3.0           5.2          2.0  virginica
#  148           6.2          3.4           5.4          2.3  virginica
#  149           5.9          3.0           5.1          1.8  virginica
#
#  [150 rows x 5 columns],
#  'car_crashes':     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
#  0    18.8     7.332    5.640          18.048       15.040       784.55
#  1    18.1     7.421    4.525          16.290       17.014      1053.48
#  2    18.6     6.510    5.208          15.624       17.856       899.47
#  3    22.4     4.032    5.824          21.056       21.280       827.34
#  4    12.0     4.200    3.360          10.920       10.680       878.41
#  5    13.6     5.032    3.808          10.744       12.920       835.50
#  6    10.8     4.968    3.888           9.396        8.856      1068.73
#  7    16.2     6.156    4.860          14.094       16.038      1137.87
#  8     5.9     2.006    1.593           5.900        5.900      1273.89
#  9    17.9     3.759    5.191          16.468       16.826      1160.13
#  10   15.6     2.964    3.900          14.820       14.508       913.15
#  11   17.5     9.450    7.175          14.350       15.225       861.18
#  12   15.3     5.508    4.437          13.005       14.994       641.96
#  13   12.8     4.608    4.352          12.032       12.288       803.11
#  14   14.5     3.625    4.205          13.775       13.775       710.46
#  15   15.7     2.669    3.925          15.229       13.659       649.06
#  16   17.8     4.806    4.272          13.706       15.130       780.45
#  17   21.4     4.066    4.922          16.692       16.264       872.51
#  18   20.5     7.175    6.765          14.965       20.090      1281.55
#  19   15.1     5.738    4.530          13.137       12.684       661.88
#  20   12.5     4.250    4.000           8.875       12.375      1048.78
#  21    8.2     1.886    2.870           7.134        6.560      1011.14
#  22   14.1     3.384    3.948          13.395       10.857      1110.61
#  23    9.6     2.208    2.784           8.448        8.448       777.18
#  24   17.6     2.640    5.456           1.760       17.600       896.07
#  25   16.1     6.923    5.474          14.812       13.524       790.32
#  26   21.4     8.346    9.416          17.976       18.190       816.21
#  27   14.9     1.937    5.215          13.857       13.410       732.28
#  28   14.7     5.439    4.704          13.965       14.553      1029.87
#  29   11.6     4.060    3.480          10.092        9.628       746.54
#  30   11.2     1.792    3.136           9.632        8.736      1301.52
#  31   18.4     3.496    4.968          12.328       18.032       869.85
#  32   12.3     3.936    3.567          10.824        9.840      1234.31
#  33   16.8     6.552    5.208          15.792       13.608       708.24
#  34   23.9     5.497   10.038          23.661       20.554       688.75
#  35   14.1     3.948    4.794          13.959       11.562       697.73
#  36   19.9     6.368    5.771          18.308       18.706       881.51
#  37   12.8     4.224    3.328           8.576       11.520       804.71
#  38   18.2     9.100    5.642          17.472       16.016       905.99
#  39   11.1     3.774    4.218          10.212        8.769      1148.99
#  40   23.9     9.082    9.799          22.944       19.359       858.97
#  41   19.4     6.014    6.402          19.012       16.684       669.31
#  42   19.5     4.095    5.655          15.990       15.795       767.91
#  43   19.4     7.760    7.372          17.654       16.878      1004.75
#  44   11.3     4.859    1.808           9.944       10.848       809.38
#  45   13.6     4.080    4.080          13.056       12.920       716.20
#  46   12.7     2.413    3.429          11.049       11.176       768.95
#  47   10.6     4.452    3.498           8.692        9.116       890.03
#  48   23.8     8.092    6.664          23.086       20.706       992.61
#  49   13.8     4.968    4.554           5.382       11.592       670.31
#  50   17.4     7.308    5.568          14.094       15.660       791.14
#
#      ins_losses abbrev
#  0       145.08     AL
#  1       133.93     AK
#  2       110.35     AZ
#  3       142.39     AR
#  4       165.63     CA
#  5       139.91     CO
#  6       167.02     CT
#  7       151.48     DE
#  8       136.05     DC
#  9       144.18     FL
#  10      142.80     GA
#  11      120.92     HI
#  12       82.75     ID
#  13      139.15     IL
#  14      108.92     IN
#  15      114.47     IA
#  16      133.80     KS
#  17      137.13     KY
#  18      194.78     LA
#  19       96.57     ME
#  20      192.70     MD
#  21      135.63     MA
#  22      152.26     MI
#  23      133.35     MN
#  24      155.77     MS
#  25      144.45     MO
#  26       85.15     MT
#  27      114.82     NE
#  28      138.71     NV
#  29      120.21     NH
#  30      159.85     NJ
#  31      120.75     NM
#  32      150.01     NY
#  33      127.82     NC
#  34      109.72     ND
#  35      133.52     OH
#  36      178.86     OK
#  37      104.61     OR
#  38      153.86     PA
#  39      148.58     RI
#  40      116.29     SC
#  41       96.87     SD
#  42      155.57     TN
#  43      156.83     TX
#  44      109.48     UT
#  45      109.61     VT
#  46      153.72     VA
#  47      111.62     WA
#  48      152.56     WV
#  49      106.62     WI
#  50      122.04     WY  ,
#  'exercise':     Unnamed: 0  id     diet  pulse    time     kind
#  0            0   1  low fat     85   1 min     rest
#  1            1   1  low fat     85  15 min     rest
#  2            2   1  low fat     88  30 min     rest
#  3            3   2  low fat     90   1 min     rest
#  4            4   2  low fat     92  15 min     rest
#  ..         ...  ..      ...    ...     ...      ...
#  85          85  29   no fat    135  15 min  running
#  86          86  29   no fat    130  30 min  running
#  87          87  30   no fat     99   1 min  running
#  88          88  30   no fat    111  15 min  running
#  89          89  30   no fat    150  30 min  running
#
#  [90 rows x 6 columns]}

# %% [markdown]
# # TIPs 데이터로 분포, 범주형 비교
# * 식당 팁 지출 데이터

# %%
tips=data['tips'].copy()
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['tip_pct']=tips['tip']/tips['total_bill']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %% [markdown]
# # histplot - 히스토그램(막대 분포도)
# * 목적(무엇을 보나): 값이 어느 구간에 많이 몰렸는지, 치우침/꼬리/이상치 감지.
# * 언제 쓰나: 연속형/이산형 분포의 첫 관찰.
# * 핵심 옵션
#      * bins(막대 수), binwidth(구간 너비), binrange(범위)
#     * stat: "count"|"probability"|"density" (밀도 비교 시 density)
#     * multiple: "layer"|"stack"|"fill" (그룹 비교)
#     * kde=True(KDE 라인 같이 표시)

# %%
plt.figure()
sns.histplot(tips['total_bill'],bins=20,stat='density',kde=True) # kde=선
plt.title('total_bill 분포')
plt.show()

# %% [markdown]
# # kdeplot-커널 밀도 추정 그래프(kde)
# * 목적: 히스토그램보다 부드러운 분포 형태 파악 (봉우리/꼬리).
#
# * 언제: 샘플이 충분하고 분포 형태 자체가 관심일 때.
#
# * 핵심 옵션
#
#
#     * fill=True(면적 채우기), bw_adjust(대역폭; 작으면 세밀, 크면 매끈)
#
#
#     * common_norm(여러 그룹 비교 시 정규화 방식)

# %%
plt.figure()
sns.kdeplot(tips['tip_pct'],fill=True, bw_adjust=1.0) 
plt.title('tip_pct 분포')
plt.show()

# %% [markdown]
# # ecdfplot=경험적 누적분포함수(ecdf)
# 목적: “x 이하의 누적 비율”을 바로 읽음(분위수·중위수 판단 용이).
#
# 언제: “50%가 얼마 이하?”, “상위 10% 컷?”처럼 백분위/분위수가 궁금할 때.
#
# 핵심 옵션
#
#
# complementary=True(1−ECDF, 역누적)
#
#
# hue(그룹별 누적곡선 비교)

# %%
plt.figure()
sns.ecdfplot(tips['tip_pct']) 
plt.title('tip_pct 누적분포')
plt.show()

# %% [markdown]
# # barplot
#
# * 목적:
#   * 범주형 변수(day)별로 연속형 값(tip_pct)의 평균(혹은 다른 통계량) 을 막대로 표현하는 그래프입니다.
# 즉, “요일별 평균 팁 비율이 얼마나 다른가?” 를 시각적으로 비교하기 위한 요약 통계형 막대그래프입니다.
#
# * 언제:
#
#   * 그룹별 평균값, 중앙값, 합계 등을 비교할 때
#   * 단순 빈도(countplot)가 아닌 집계된 값의 차이를 보고 싶을 때
#   * 그룹 간 차이의 대략적인 경향을 파악할 때
#
# * errorbar (오차막대)란?
#   * 막대 위아래의 가늘고 짧은 선(line)
#   * 데이터의 변동성(흩어짐 정도) 을 시각적으로 표현
#   * 주로 표준편차(sd) 또는 표준오차(se) 또는 신뢰구간(ci) 으로 표시됨

# %%
plt.figure()
sns.barplot(data=tips,x='day',y='tip_pct',estimator=np.mean,errorbar=('ci',95)) 
plt.title('요일별 평균 오차 신뢰구간 95%')
plt.show()

# %% [markdown]
# # boxplot
#
# * 목적:
#   * 데이터의 중앙값·사분위수·이상치를 한눈에 보여주는 요약 통계 시각화입니다.
#   * 분포의 중심, 퍼짐(분산), 비대칭성, 이상값(outlier)을 간결하게 비교할 수 있습니다.
# * 언제:
#   * 범주별 분포 비교를 할 때 (예: 요일별, 성별, 그룹별)
#   * 평균보다 중앙값 중심의 통계가 중요할 때
#   * 이상치 탐색이나 데이터 편향 확인이 필요할 때

# %%
plt.figure()
sns.boxplot(data=tips,x='day',y='total_bill',hue='time') 
plt.title('요일별, 시간별 total_bill 분포')
plt.show()

# %% [markdown]
# # violinplot
#
# * 목적:
# 데이터의 분포 형태를 시각적으로 표현하면서,
# **중앙값(중앙선)**과 사분위 범위를 동시에 보여줍니다.
# 즉, boxplot(상자그림) + KDE(밀도분포)의 결합형 그래프입니다.
# 이 코드에서는 요일(day)과 식사시간(time)에 따른
# 총 지출액(total_bill)의 분포를 한눈에 비교합니다.
# 언제:
#
# 범주별 분포 비교를 하고 싶을 때
#
# 단순 평균/오차막대(barplot)보다 분포의 모양을 강조하고 싶을 때
#
# 특히 값이 쌍봉형(두 개의 봉우리) 이거나 비대칭적 분포일 때 유용합니다.
#
# split=True를 사용하면 두 그룹(hue)을 한 바이올린 안에서 좌우로 나눠 비교할 수 있습니다.

# %%
plt.figure()
sns.violinplot(data=tips,x='day',y='total_bill',hue='time',split=True, cut=0, inner='quartile') 
plt.title('요일별, 시간별 total_bill 분포(violin plot)')
plt.show()

# %% [markdown]
# # stripplot
# * 범주형 데이터의 분포 확인
# * “요일별 팁 비율이 어떻게 퍼져 있나?”
# * scatterplot → “팁 비율이 총금액과 어떤 관계가 있나?”

# %%
plt.figure()
sns.stripplot(data=tips,x='sex',y='tip_pct',jitter=0.25, alpha=0.6) 
plt.title('성별에 따른 tip_pct 산포도')
plt.show()

# %% [markdown]
# # Penguins 데이터로 산점도, 회귀, 다변량 관계 그래프

# %%
pg=data['penguins'].dropna()
pg
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# # scatterplot 산점도 그래프
#
# * 목적
#   * 두 연속형 변수 간의 관계(상관관계)를 시각화
#   * 데이터가 어떤 패턴을 가지는지,
#   * 즉 “부리가 길수록 깊이도 깊은가?”, “그룹별 차이는 있는가?” 를 한눈에 파악하기 위해 사용

# %%
pg.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
plt.figure()
sns.scatterplot(data=pg,x='bill_length_mm',y='bill_depth_mm',hue='species',style='sex') 
plt.title('bill_length,bill_depth의 종별, 성별별 산포도')
plt.show()

# %% [markdown]
# # lmplot
# * 목적
#   * 두 연속형 변수 간의 선형 관계(상관관계) 를 보여줍니다.
#   * 단순한 점(산점도) 대신 회귀선(추세선) 을 추가해,
#   * “x가 증가할 때 y가 어떻게 변하는지”를 직관적으로 파악하게 합니다.

# %%
plt.figure()
sns.lmplot(data=pg,x='flipper_length_mm',y='body_mass_g',hue="species",
          height=4.5,aspect=1.2) 
plt.title('flipper_length_mm VS body_mass_g 종별 회귀 그래프')
plt.show()

# %% [markdown]
# # pairplot
# * 목적
#   * 여러 연속형 변수들 간의 관계를 한 번에 시각화
#   * 산점도(scatterplot) 와 히스토그램(histogram) 이 결합된 형태
#   * 변수 간 상관관계 패턴을 빠르게 파악할 수 있음

# %%
pg.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
plt.figure()
sns.pairplot(pg[['bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g','species']],hue='species',corner=True) 
# plt.title('flipper_length_mm VS body_mass_g 종별 회귀 그래프')
plt.show()

# %% [markdown]
# # Flights 데이터로 시계열 그래프, 히트맵

# %%
flight=data['flights'].copy()
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
month_order=list(flight['month'].unique())
month_order
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
flight['month_num']=flight['month'].apply(lambda m: month_order.index(m)+1)
flight
# Out:
#      year month  passengers month_num
# 0    1949   Jan         112         1
# 1    1949   Feb         118         2
# 2    1949   Mar         132         3
# 3    1949   Apr         129         4
# 4    1949   May         121         5
# ..    ...   ...         ...       ...
# 139  1960   Aug         606         8
# 140  1960   Sep         508         9
# 141  1960   Oct         461        10
# 142  1960   Nov         390        11
# 143  1960   Dec         432        12
#
# [144 rows x 4 columns]

# %%
flight['date']=pd.to_datetime(flight['year'].astype(str)+'-'+flight['month_num'].astype(str)+'-01')
flight
# Out:
#      year month  passengers month_num       date
# 0    1949   Jan         112         1 1949-01-01
# 1    1949   Feb         118         2 1949-02-01
# 2    1949   Mar         132         3 1949-03-01
# 3    1949   Apr         129         4 1949-04-01
# 4    1949   May         121         5 1949-05-01
# ..    ...   ...         ...       ...        ...
# 139  1960   Aug         606         8 1960-08-01
# 140  1960   Sep         508         9 1960-09-01
# 141  1960   Oct         461        10 1960-10-01
# 142  1960   Nov         390        11 1960-11-01
# 143  1960   Dec         432        12 1960-12-01
#
# [144 rows x 5 columns]

# %%
flight=flight.sort_values(by='date')
flight
# Out:
#      year month  passengers month_num       date
# 0    1949   Jan         112         1 1949-01-01
# 1    1949   Feb         118         2 1949-02-01
# 2    1949   Mar         132         3 1949-03-01
# 3    1949   Apr         129         4 1949-04-01
# 4    1949   May         121         5 1949-05-01
# ..    ...   ...         ...       ...        ...
# 139  1960   Aug         606         8 1960-08-01
# 140  1960   Sep         508         9 1960-09-01
# 141  1960   Oct         461        10 1960-10-01
# 142  1960   Nov         390        11 1960-11-01
# 143  1960   Dec         432        12 1960-12-01
#
# [144 rows x 5 columns]

# %% [markdown]
# # lineplot 선 그래프, 시계열 추세선
#
# * 시간(time) 에 따른 데이터의 추세(Trend) 를 보여주는 시각화
# * 계절성(Seasonality)이나 패턴(증가/감소)을 쉽게 파악할 수 있음
# * 데이터가 시간 순서로 정렬되어 있을 때 가장 기본적이고 중요한 형태

# %%
plt.figure()
sns.lineplot(x=flight['date'],y=flight['passengers']) 
plt.title('한국 여객 수 추이')
plt.xlabel('date')
plt.ylabel('passengers')
plt.show()
# 계절성 추세(수영장, 항공 등)

# %% [markdown]
# # heatmap 히트맵(Heatmap) 또는 열지도
#
# * 2차원 데이터(행×열) 를 색의 강도로 표현하는 그래프
# * 시간 패턴, 계절성, 클러스터링 등을 직관적으로 파악할 때 사용
# * 데이터의 크기나 밀도를 색상 차이로 즉시 인식 가능

# %%
table=flight.pivot(index='month',columns="year",values='passengers')
plt.figure()
sns.heatmap(table,annot=False,fmt='g') 
plt.title('월별 연도별 항공 이용객 히트맵')
plt.show()

# %% [markdown]
# # iris 붓꽃데이터 2dkde 분포그래프 그리기

# %%
iris=data['iris'].copy()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.figure()
sns.kdeplot(data=iris,x='sepal_length',y='sepal_width',fill=True, thresh=0.05) 
plt.title('2D KDE sepal_length vs sepal_width')
plt.show()

# %% [markdown]
# # Car Crashes- 상관과 회귀 그래프

# %%
car=data['car_crashes'].copy()
car.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
car.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
cols= car[['speeding', 'alcohol', 'not_distracted', 'no_previous',
       'ins_premium', 'ins_losses']]

# %%
corr=cols.corr()
corr
# Out:
#                 speeding   alcohol  not_distracted  no_previous  ins_premium  \
# speeding        1.000000  0.669719        0.588010     0.571976    -0.077675
# alcohol         0.669719  1.000000        0.732816     0.783520    -0.170612
# not_distracted  0.588010  0.732816        1.000000     0.747307    -0.174856
# no_previous     0.571976  0.783520        0.747307     1.000000    -0.156895
# ins_premium    -0.077675 -0.170612       -0.174856    -0.156895     1.000000
# ins_losses     -0.065928 -0.112547       -0.075970    -0.006359     0.623116
#
#                 ins_losses
# speeding         -0.065928
# alcohol          -0.112547
# not_distracted   -0.075970
# no_previous      -0.006359
# ins_premium       0.623116
# ins_losses        1.000000

# %%
plt.figure()
sns.heatmap(corr,annot=True, vmin=-1,vmax=1, center=0, fmt='.2f') 
plt.title('car crashes 상관 히트맵')
plt.show()

# %% [markdown]
# # regplot 회귀선 산점도
#
# * 두 연속형 변수 간의 선형 관계를 시각적으로 확인
# * 단순한 scatterplot에 회귀선과 신뢰구간을 추가하여
# * “x가 증가하면 y가 함께 증가하는가?”를 직관적으로 파악

# %%
plt.figure()
sns.regplot(data=car, x='alcohol',y='speeding')
plt.title('alcohol vs speeding 회귀 산점도')
plt.show()
